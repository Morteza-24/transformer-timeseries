# %%
import os
import random
import sys
from argparse import Namespace
from pathlib import Path

import numpy as np
import torch

# Run from the iTransformer project root so dataset/checkpoint paths resolve correctly.
ITRANSFORMER_ROOT = (Path.cwd().parent / "models" / "itransformer").resolve()
os.chdir(ITRANSFORMER_ROOT)
sys.path.insert(0, str(ITRANSFORMER_ROOT))

# %%
from experiments.exp_long_term_forecasting import Exp_Long_Term_Forecast
from experiments.exp_long_term_forecasting_partial import Exp_Long_Term_Forecast_Partial

# User-specified arguments; everything else uses run.py defaults.
args = Namespace(
    # user-specified
    is_training=1,
    root_path="../../datasets/",
    data_path="traffic.csv",
    model_id="traffic_96_96",
    model="iTransformer",
    data="custom",
    features="M",
    seq_len=96,
    pred_len=96,
    e_layers=4,
    enc_in=862,
    dec_in=862,
    c_out=862,
    des="Exp",
    d_model=512,
    d_ff=512,
    batch_size=16,
    learning_rate=0.001,
    itr=1,
    # defaults from run.py
    target="OT",
    freq="h",
    checkpoints="./checkpoints/",
    label_len=48,
    n_heads=8,
    d_layers=1,
    moving_avg=25,
    factor=1,
    distil=True,
    dropout=0.1,
    embed="timeF",
    activation="gelu",
    output_attention=False,
    do_predict=False,
    num_workers=10,
    train_epochs=9,
    patience=3,
    loss="MSE",
    lradj="type1",
    use_amp=False,
    use_gpu=True,
    gpu=0,
    use_multi_gpu=False,
    devices="0,1,2,3",
    exp_name="MTSF",
    channel_independence=False,
    inverse=False,
    class_strategy="projection",
    target_root_path="./data/traffic/",
    target_data_path="traffic.csv",
    efficient_training=False,
    use_norm=True,
    partial_start_index=0,
)

fix_seed = 24
random.seed(fix_seed)
torch.manual_seed(fix_seed)
np.random.seed(fix_seed)

args.use_gpu = True if torch.cuda.is_available() and args.use_gpu else False

if args.use_gpu and args.use_multi_gpu:
    args.devices = args.devices.replace(" ", "")
    device_ids = args.devices.split(",")
    args.device_ids = [int(id_) for id_ in device_ids]
    args.gpu = args.device_ids[0]

print("Args in experiment:")
print(args)

if args.exp_name == "partial_train":
    Exp = Exp_Long_Term_Forecast_Partial
else:
    Exp = Exp_Long_Term_Forecast

if args.is_training:
    for ii in range(args.itr):
        setting = "{}_{}_{}_{}_ft{}_sl{}_ll{}_pl{}_dm{}_nh{}_el{}_dl{}_df{}_fc{}_eb{}_dt{}_{}_{}".format(
            args.model_id,
            args.model,
            args.data,
            args.features,
            args.seq_len,
            args.label_len,
            args.pred_len,
            args.d_model,
            args.n_heads,
            args.e_layers,
            args.d_layers,
            args.d_ff,
            args.factor,
            args.embed,
            args.distil,
            args.des,
            args.class_strategy,
            ii,
        )

        exp = Exp(args)
        print(">>>>>>>start training : {}>>>>>>>>>>>>>>>>>>>>>>>>>>".format(setting))
        exp.train(setting)

        print(">>>>>>>testing : {}<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<".format(setting))
        exp.test(setting)

        if args.do_predict:
            print(">>>>>>>predicting : {}<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<".format(setting))
            exp.predict(setting, True)

        torch.cuda.empty_cache()
else:
    ii = 0
    setting = "{}_{}_{}_{}_ft{}_sl{}_ll{}_pl{}_dm{}_nh{}_el{}_dl{}_df{}_fc{}_eb{}_dt{}_{}_{}".format(
        args.model_id,
        args.model,
        args.data,
        args.features,
        args.seq_len,
        args.label_len,
        args.pred_len,
        args.d_model,
        args.n_heads,
        args.e_layers,
        args.d_layers,
        args.d_ff,
        args.factor,
        args.embed,
        args.distil,
        args.des,
        args.class_strategy,
        ii,
    )

    exp = Exp(args)
    print(">>>>>>>testing : {}<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<".format(setting))
    exp.test(setting, test=1)
    torch.cuda.empty_cache()
# Out:
# Args in experiment:
# Namespace(is_training=1, root_path='../../datasets/', data_path='traffic.csv', model_id='traffic_96_96', model='iTransformer', data='custom', features='M', seq_len=96, pred_len=96, e_layers=4, enc_in=862, dec_in=862, c_out=862, des='Exp', d_model=512, d_ff=512, batch_size=16, learning_rate=0.001, itr=1, target='OT', freq='h', checkpoints='./checkpoints/', label_len=48, n_heads=8, d_layers=1, moving_avg=25, factor=1, distil=True, dropout=0.1, embed='timeF', activation='gelu', output_attention=False, do_predict=False, num_workers=10, train_epochs=9, patience=3, loss='MSE', lradj='type1', use_amp=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', exp_name='MTSF', channel_independence=False, inverse=False, class_strategy='projection', target_root_path='./data/traffic/', target_data_path='traffic.csv', efficient_training=False, use_norm=True, partial_start_index=0)
# Use GPU: cuda:0
# >>>>>>>start training : traffic_96_96_iTransformer_custom_M_ft96_sl48_ll96_pl512_dm8_nh4_el1_dl512_df1_fctimeF_ebTrue_dtExp_projection_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 12089
# val 1661
# test 3413
# 	iters: 100, epoch: 1 | loss: 0.4160715
# 	speed: 0.2641s/iter; left time: 1768.7440s
# 	iters: 200, epoch: 1 | loss: 0.3342308
# 	speed: 0.2599s/iter; left time: 1714.1502s
# 	iters: 300, epoch: 1 | loss: 0.3337172
# 	speed: 0.2599s/iter; left time: 1688.3578s
# 	iters: 400, epoch: 1 | loss: 0.2946044
# 	speed: 0.2599s/iter; left time: 1662.4782s
# 	iters: 500, epoch: 1 | loss: 0.3210113
# 	speed: 0.2599s/iter; left time: 1636.5486s
# 	iters: 600, epoch: 1 | loss: 0.3031853
# 	speed: 0.2599s/iter; left time: 1610.4351s
# 	iters: 700, epoch: 1 | loss: 0.2833120
# 	speed: 0.2599s/iter; left time: 1584.3813s
# Epoch: 1 cost time: 196.81594038009644
# Epoch: 1, Steps: 755 | Train Loss: 0.3419181 Vali Loss: 0.4190592 Test Loss: 0.4633555
# Validation loss decreased (inf --> 0.419059).  Saving model ...
# Updating learning rate to 0.001
# 	iters: 100, epoch: 2 | loss: 0.2711094
# 	speed: 0.8097s/iter; left time: 4810.7240s
# 	iters: 200, epoch: 2 | loss: 0.2930303
# 	speed: 0.2599s/iter; left time: 1518.1202s
# 	iters: 300, epoch: 2 | loss: 0.3000171
# 	speed: 0.2599s/iter; left time: 1492.1594s
# 	iters: 400, epoch: 2 | loss: 0.2758824
# 	speed: 0.2599s/iter; left time: 1466.2549s
# 	iters: 500, epoch: 2 | loss: 0.2841558
# 	speed: 0.2599s/iter; left time: 1440.2139s
# 	iters: 600, epoch: 2 | loss: 0.2722872
# 	speed: 0.2599s/iter; left time: 1414.1815s
# 	iters: 700, epoch: 2 | loss: 0.3355122
# 	speed: 0.2599s/iter; left time: 1388.2360s
# Epoch: 2 cost time: 196.95310020446777
# Epoch: 2, Steps: 755 | Train Loss: 0.2886368 Vali Loss: 0.4099174 Test Loss: 0.4514885
# Validation loss decreased (0.419059 --> 0.409917).  Saving model ...
# Updating learning rate to 0.0005
# 	iters: 100, epoch: 3 | loss: 0.2445556
# 	speed: 0.8337s/iter; left time: 4323.8121s
# 	iters: 200, epoch: 3 | loss: 0.2755206
# 	speed: 0.2599s/iter; left time: 1321.9058s
# 	iters: 300, epoch: 3 | loss: 0.2834398
# 	speed: 0.2599s/iter; left time: 1295.9081s
# 	iters: 400, epoch: 3 | loss: 0.2571486
# 	speed: 0.2599s/iter; left time: 1269.9634s
# 	iters: 500, epoch: 3 | loss: 0.2443498
# 	speed: 0.2599s/iter; left time: 1243.9573s
# 	iters: 600, epoch: 3 | loss: 0.2446695
# 	speed: 0.2599s/iter; left time: 1217.9434s
# 	iters: 700, epoch: 3 | loss: 0.2795673
# 	speed: 0.2599s/iter; left time: 1191.9952s
# Epoch: 3 cost time: 196.99655294418335
# Epoch: 3, Steps: 755 | Train Loss: 0.2591517 Vali Loss: 0.3766171 Test Loss: 0.4134485
# Validation loss decreased (0.409917 --> 0.376617).  Saving model ...
# Updating learning rate to 0.00025
# 	iters: 100, epoch: 4 | loss: 0.2492968
# 	speed: 0.8215s/iter; left time: 3640.2762s
# 	iters: 200, epoch: 4 | loss: 0.2562159
# 	speed: 0.2599s/iter; left time: 1125.6784s
# 	iters: 300, epoch: 4 | loss: 0.2482667
# 	speed: 0.2599s/iter; left time: 1099.7111s
# 	iters: 400, epoch: 4 | loss: 0.2463379
# 	speed: 0.2599s/iter; left time: 1073.7921s
# 	iters: 500, epoch: 4 | loss: 0.2346951
# 	speed: 0.2599s/iter; left time: 1047.6641s
# 	iters: 600, epoch: 4 | loss: 0.2347490
# 	speed: 0.2599s/iter; left time: 1021.7307s
# 	iters: 700, epoch: 4 | loss: 0.2123634
# 	speed: 0.2599s/iter; left time: 995.7445s
# Epoch: 4 cost time: 196.97865653038025
# Epoch: 4, Steps: 755 | Train Loss: 0.2475523 Vali Loss: 0.3708150 Test Loss: 0.4068431
# Validation loss decreased (0.376617 --> 0.370815).  Saving model ...
# Updating learning rate to 0.000125
# 	iters: 100, epoch: 5 | loss: 0.2312181
# 	speed: 0.8293s/iter; left time: 3048.6166s
# 	iters: 200, epoch: 5 | loss: 0.2530755
# 	speed: 0.2599s/iter; left time: 929.4835s
# 	iters: 300, epoch: 5 | loss: 0.2944264
# 	speed: 0.2599s/iter; left time: 903.4478s
# 	iters: 400, epoch: 5 | loss: 0.2288897
# 	speed: 0.2599s/iter; left time: 877.5169s
# 	iters: 500, epoch: 5 | loss: 0.2404344
# 	speed: 0.2599s/iter; left time: 851.4818s
# 	iters: 600, epoch: 5 | loss: 0.2313682
# 	speed: 0.2599s/iter; left time: 825.4708s
# 	iters: 700, epoch: 5 | loss: 0.2615257
# 	speed: 0.2599s/iter; left time: 799.5667s
# Epoch: 5 cost time: 196.97853565216064
# Epoch: 5, Steps: 755 | Train Loss: 0.2401683 Vali Loss: 0.3666049 Test Loss: 0.4003451
# Validation loss decreased (0.370815 --> 0.366605).  Saving model ...
# Updating learning rate to 6.25e-05
# 	iters: 100, epoch: 6 | loss: 0.2256609
# 	speed: 0.8383s/iter; left time: 2448.7684s
# 	iters: 200, epoch: 6 | loss: 0.2135292
# 	speed: 0.2599s/iter; left time: 733.2036s
# 	iters: 300, epoch: 6 | loss: 0.2757120
# 	speed: 0.2599s/iter; left time: 707.2138s
# 	iters: 400, epoch: 6 | loss: 0.2020990
# 	speed: 0.2599s/iter; left time: 681.2380s
# 	iters: 500, epoch: 6 | loss: 0.2173820
# 	speed: 0.2599s/iter; left time: 655.2749s
# 	iters: 600, epoch: 6 | loss: 0.2549926
# 	speed: 0.2599s/iter; left time: 629.2658s
# 	iters: 700, epoch: 6 | loss: 0.2210819
# 	speed: 0.2599s/iter; left time: 603.2580s
# Epoch: 6 cost time: 196.99671864509583
# Epoch: 6, Steps: 755 | Train Loss: 0.2352343 Vali Loss: 0.3620791 Test Loss: 0.3957216
# Validation loss decreased (0.366605 --> 0.362079).  Saving model ...
# Updating learning rate to 3.125e-05
# 	iters: 100, epoch: 7 | loss: 0.2356413
# 	speed: 0.8193s/iter; left time: 1774.6840s
# 	iters: 200, epoch: 7 | loss: 0.2292468
# 	speed: 0.2599s/iter; left time: 536.9760s
# 	iters: 300, epoch: 7 | loss: 0.2246468
# 	speed: 0.2599s/iter; left time: 511.0086s
# 	iters: 400, epoch: 7 | loss: 0.2084867
# 	speed: 0.2599s/iter; left time: 485.0208s
# 	iters: 500, epoch: 7 | loss: 0.2240330
# 	speed: 0.2599s/iter; left time: 458.9969s
# 	iters: 600, epoch: 7 | loss: 0.1978431
# 	speed: 0.2599s/iter; left time: 433.0288s
# 	iters: 700, epoch: 7 | loss: 0.2659455
# 	speed: 0.2599s/iter; left time: 407.0226s
# Epoch: 7 cost time: 196.95337057113647
# Epoch: 7, Steps: 755 | Train Loss: 0.2324245 Vali Loss: 0.3610057 Test Loss: 0.3944613
# Validation loss decreased (0.362079 --> 0.361006).  Saving model ...
# Updating learning rate to 1.5625e-05
# 	iters: 100, epoch: 8 | loss: 0.2294213
# 	speed: 0.8236s/iter; left time: 1162.0309s
# 	iters: 200, epoch: 8 | loss: 0.2264518
# 	speed: 0.2599s/iter; left time: 340.7474s
# 	iters: 300, epoch: 8 | loss: 0.2111371
# 	speed: 0.2599s/iter; left time: 314.7749s
# 	iters: 400, epoch: 8 | loss: 0.2502186
# 	speed: 0.2599s/iter; left time: 288.7633s
# 	iters: 500, epoch: 8 | loss: 0.2369610
# 	speed: 0.2599s/iter; left time: 262.7642s
# 	iters: 600, epoch: 8 | loss: 0.2352302
# 	speed: 0.2599s/iter; left time: 236.7874s
# 	iters: 700, epoch: 8 | loss: 0.2354829
# 	speed: 0.2599s/iter; left time: 210.7923s
# Epoch: 8 cost time: 197.0093514919281
# Epoch: 8, Steps: 755 | Train Loss: 0.2309404 Vali Loss: 0.3602163 Test Loss: 0.3937000
# Validation loss decreased (0.361006 --> 0.360216).  Saving model ...
# Updating learning rate to 7.8125e-06
# 	iters: 100, epoch: 9 | loss: 0.2561360
# 	speed: 0.8257s/iter; left time: 541.6829s
# 	iters: 200, epoch: 9 | loss: 0.2091790
# 	speed: 0.2599s/iter; left time: 144.5121s
# 	iters: 300, epoch: 9 | loss: 0.2303554
# 	speed: 0.2599s/iter; left time: 118.5238s
# 	iters: 400, epoch: 9 | loss: 0.2334411
# 	speed: 0.2599s/iter; left time: 92.5324s
# 	iters: 500, epoch: 9 | loss: 0.2265213
# 	speed: 0.2599s/iter; left time: 66.5392s
# 	iters: 600, epoch: 9 | loss: 0.2231925
# 	speed: 0.2599s/iter; left time: 40.5465s
# 	iters: 700, epoch: 9 | loss: 0.2452471
# 	speed: 0.2599s/iter; left time: 14.5560s
# Epoch: 9 cost time: 197.00329899787903
# Epoch: 9, Steps: 755 | Train Loss: 0.2301549 Vali Loss: 0.3596876 Test Loss: 0.3931304
# Validation loss decreased (0.360216 --> 0.359688).  Saving model ...
# Updating learning rate to 3.90625e-06
# >>>>>>>testing : traffic_96_96_iTransformer_custom_M_ft96_sl48_ll96_pl512_dm8_nh4_el1_dl512_df1_fctimeF_ebTrue_dtExp_projection_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 3413
# test shape: (3413, 1, 96, 862) (3413, 1, 96, 862)
# test shape: (3413, 96, 862) (3413, 96, 862)
# mse:0.39313066005706787, mae:0.268658846616745
