# %%
import os
import random
import sys
import time
from argparse import Namespace
from pathlib import Path

import numpy as np
import torch

# Run from the RLinear project root so dataset/checkpoint paths resolve correctly.
RLINEAR_ROOT = (Path.cwd().parent / "models" / "rlinear").resolve()
os.chdir(RLINEAR_ROOT)
sys.path.insert(0, str(RLINEAR_ROOT))

# %%
from exp.exp_main import Exp_Main

# User-specified arguments; everything else uses run.py defaults.
args = Namespace(
    # user-specified
    is_training=1,
    data_path="traffic.csv",
    data="custom",
    features="M",
    channel=862,
    itr=1,
    learning_rate=0.001,
    model="RLinear",
    rev=True,
    seq_len=96,
    pred_len=96,
    drop=0,
    # defaults from run.py
    root_path="../../datasets/",
    target="OT",
    freq="h",
    checkpoints="./checkpoints/",
    individual=False,
    seg=20,
    d_model=512,
    layers=2,
    embed="timeF",
    do_predict=False,
    num_workers=10,
    train_epochs=9,
    batch_size=16,
    patience=10,
    lradj="type1",
    use_amp=False,
    use_gpu=True,
    gpu=0,
    use_multi_gpu=False,
    devices="0,1,2,3",
)

fix_seed = 1024
random.seed(fix_seed)
torch.manual_seed(fix_seed)
np.random.seed(fix_seed)

args.use_gpu = True if torch.cuda.is_available() and args.use_gpu else False

if args.use_gpu and args.use_multi_gpu:
    args.devices = args.devices.replace(" ", "")
    device_ids = args.devices.split(",")
    args.device_ids = [int(id_) for id_ in device_ids]
    args.gpu = args.device_ids[0]

print("Args in experiment:")
print(args)

Exp = Exp_Main

if args.is_training:
    for ii in range(args.itr):
        setting = "{}_{}_ft{}_sl{}_pl{}_dm{}_eb{}_{}".format(
            args.model,
            args.data_path[:-4],
            args.features,
            args.seq_len,
            args.pred_len,
            args.d_model,
            args.embed,
            ii,
        )

        exp = Exp(args)
        print(">>>>>>>start training : {}>>>>>>>>>>>>>>>>>>>>>>>>>>".format(setting))
        exp.train(setting)

        time_now = time.time()
        print(">>>>>>>testing : {}<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<".format(setting))
        exp.test(setting)
        print("Inference time: ", time.time() - time_now)

        if args.do_predict:
            print(">>>>>>>predicting : {}<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<".format(setting))
            exp.predict(setting, True)

        torch.cuda.empty_cache()
else:
    ii = 0
    setting = "{}_{}_ft{}_sl{}_pl{}_dm{}_eb{}_{}".format(
        args.model,
        args.data_path[:-4],
        args.features,
        args.seq_len,
        args.pred_len,
        args.d_model,
        args.embed,
        ii,
    )

    exp = Exp(args)
    print(">>>>>>>testing : {}<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<".format(setting))
    exp.test(setting, test=1)
    torch.cuda.empty_cache()
# Out:
# Args in experiment:
# Namespace(is_training=1, data_path='traffic.csv', data='custom', features='M', channel=862, itr=1, learning_rate=0.001, model='RLinear', rev=True, seq_len=96, pred_len=96, drop=0, root_path='../../datasets/', target='OT', freq='h', checkpoints='./checkpoints/', individual=False, seg=20, d_model=512, layers=2, embed='timeF', do_predict=False, num_workers=10, train_epochs=9, batch_size=16, patience=10, lradj='type1', use_amp=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3')
# Use GPU: cuda:0
# Number of parameters: 0.01M
# >>>>>>>start training : RLinear_traffic_ftM_sl96_pl96_dm512_ebtimeF_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 12089
# val 1661
# test 3413
# 	iters: 100, epoch: 1 | loss: 0.5277006
# 	speed: 0.0167s/iter; left time: 112.0334s
# 	iters: 200, epoch: 1 | loss: 0.4722129
# 	speed: 0.0125s/iter; left time: 82.7707s
# 	iters: 300, epoch: 1 | loss: 0.4952770
# 	speed: 0.0117s/iter; left time: 76.1778s
# 	iters: 400, epoch: 1 | loss: 0.4849763
# 	speed: 0.0120s/iter; left time: 76.4423s
# 	iters: 500, epoch: 1 | loss: 0.4364234
# 	speed: 0.0122s/iter; left time: 76.7392s
# 	iters: 600, epoch: 1 | loss: 0.4261959
# 	speed: 0.0117s/iter; left time: 72.3536s
# 	iters: 700, epoch: 1 | loss: 0.3915364
# 	speed: 0.0115s/iter; left time: 70.0014s
# Epoch: 1 cost time: 9.542399406433105
# Epoch: 1, Steps: 755 | Train Loss: 0.4732053 Vali Loss: 0.5555207 Test Loss: 0.6624590
# Validation loss decreased (inf --> 0.555521).  Saving model ...
# Updating learning rate to 0.001
# 	iters: 100, epoch: 2 | loss: 0.3873304
# 	speed: 0.0731s/iter; left time: 434.3478s
# 	iters: 200, epoch: 2 | loss: 0.4452852
# 	speed: 0.0117s/iter; left time: 68.5504s
# 	iters: 300, epoch: 2 | loss: 0.4239103
# 	speed: 0.0118s/iter; left time: 67.8317s
# 	iters: 400, epoch: 2 | loss: 0.3856654
# 	speed: 0.0113s/iter; left time: 63.5673s
# 	iters: 500, epoch: 2 | loss: 0.4082846
# 	speed: 0.0120s/iter; left time: 66.4592s
# 	iters: 600, epoch: 2 | loss: 0.3844525
# 	speed: 0.0118s/iter; left time: 64.4578s
# 	iters: 700, epoch: 2 | loss: 0.4106590
# 	speed: 0.0120s/iter; left time: 64.0990s
# Epoch: 2 cost time: 9.47819209098816
# Epoch: 2, Steps: 755 | Train Loss: 0.4158987 Vali Loss: 0.5476614 Test Loss: 0.6516610
# Validation loss decreased (0.555521 --> 0.547661).  Saving model ...
# Updating learning rate to 0.0005
# 	iters: 100, epoch: 3 | loss: 0.4292068
# 	speed: 0.0739s/iter; left time: 383.2870s
# 	iters: 200, epoch: 3 | loss: 0.4177030
# 	speed: 0.0117s/iter; left time: 59.4178s
# 	iters: 300, epoch: 3 | loss: 0.3788874
# 	speed: 0.0120s/iter; left time: 59.9296s
# 	iters: 400, epoch: 3 | loss: 0.4357648
# 	speed: 0.0117s/iter; left time: 57.2376s
# 	iters: 500, epoch: 3 | loss: 0.4117040
# 	speed: 0.0116s/iter; left time: 55.6349s
# 	iters: 600, epoch: 3 | loss: 0.4659321
# 	speed: 0.0117s/iter; left time: 54.7162s
# 	iters: 700, epoch: 3 | loss: 0.4325557
# 	speed: 0.0117s/iter; left time: 53.6944s
# Epoch: 3 cost time: 9.483238935470581
# Epoch: 3, Steps: 755 | Train Loss: 0.4117480 Vali Loss: 0.5443987 Test Loss: 0.6481475
# Validation loss decreased (0.547661 --> 0.544399).  Saving model ...
# Updating learning rate to 0.00025
# 	iters: 100, epoch: 4 | loss: 0.4736428
# 	speed: 0.0749s/iter; left time: 331.8050s
# 	iters: 200, epoch: 4 | loss: 0.3794558
# 	speed: 0.0116s/iter; left time: 50.4522s
# 	iters: 300, epoch: 4 | loss: 0.4692532
# 	speed: 0.0117s/iter; left time: 49.5413s
# 	iters: 400, epoch: 4 | loss: 0.3544601
# 	speed: 0.0115s/iter; left time: 47.5478s
# 	iters: 500, epoch: 4 | loss: 0.4320964
# 	speed: 0.0119s/iter; left time: 48.1520s
# 	iters: 600, epoch: 4 | loss: 0.3968939
# 	speed: 0.0127s/iter; left time: 49.9097s
# 	iters: 700, epoch: 4 | loss: 0.4508425
# 	speed: 0.0122s/iter; left time: 46.7695s
# Epoch: 4 cost time: 9.591554164886475
# Epoch: 4, Steps: 755 | Train Loss: 0.4104084 Vali Loss: 0.5449523 Test Loss: 0.6488690
# EarlyStopping counter: 1 out of 10
# Updating learning rate to 0.000125
# 	iters: 100, epoch: 5 | loss: 0.4069422
# 	speed: 0.0731s/iter; left time: 268.6154s
# 	iters: 200, epoch: 5 | loss: 0.4148978
# 	speed: 0.0119s/iter; left time: 42.6007s
# 	iters: 300, epoch: 5 | loss: 0.3508979
# 	speed: 0.0122s/iter; left time: 42.3291s
# 	iters: 400, epoch: 5 | loss: 0.4451056
# 	speed: 0.0118s/iter; left time: 39.9424s
# 	iters: 500, epoch: 5 | loss: 0.3826048
# 	speed: 0.0118s/iter; left time: 38.7000s
# 	iters: 600, epoch: 5 | loss: 0.4134648
# 	speed: 0.0120s/iter; left time: 38.2211s
# 	iters: 700, epoch: 5 | loss: 0.3847254
# 	speed: 0.0123s/iter; left time: 37.7747s
# Epoch: 5 cost time: 9.583752632141113
# Epoch: 5, Steps: 755 | Train Loss: 0.4098978 Vali Loss: 0.5434437 Test Loss: 0.6469873
# Validation loss decreased (0.544399 --> 0.543444).  Saving model ...
# Updating learning rate to 6.25e-05
# 	iters: 100, epoch: 6 | loss: 0.4023097
# 	speed: 0.0728s/iter; left time: 212.7040s
# 	iters: 200, epoch: 6 | loss: 0.4123990
# 	speed: 0.0124s/iter; left time: 35.1106s
# 	iters: 300, epoch: 6 | loss: 0.4136644
# 	speed: 0.0120s/iter; left time: 32.5947s
# 	iters: 400, epoch: 6 | loss: 0.4360755
# 	speed: 0.0117s/iter; left time: 30.6585s
# 	iters: 500, epoch: 6 | loss: 0.3856735
# 	speed: 0.0114s/iter; left time: 28.8196s
# 	iters: 600, epoch: 6 | loss: 0.4262669
# 	speed: 0.0118s/iter; left time: 28.6090s
# 	iters: 700, epoch: 6 | loss: 0.3987374
# 	speed: 0.0119s/iter; left time: 27.5899s
# Epoch: 6 cost time: 9.466148614883423
# Epoch: 6, Steps: 755 | Train Loss: 0.4095277 Vali Loss: 0.5435115 Test Loss: 0.6467141
# EarlyStopping counter: 1 out of 10
# Updating learning rate to 3.125e-05
# 	iters: 100, epoch: 7 | loss: 0.3755878
# 	speed: 0.0731s/iter; left time: 158.3858s
# 	iters: 200, epoch: 7 | loss: 0.3821684
# 	speed: 0.0115s/iter; left time: 23.8274s
# 	iters: 300, epoch: 7 | loss: 0.4301339
# 	speed: 0.0121s/iter; left time: 23.7191s
# 	iters: 400, epoch: 7 | loss: 0.3855581
# 	speed: 0.0119s/iter; left time: 22.2462s
# 	iters: 500, epoch: 7 | loss: 0.3850072
# 	speed: 0.0115s/iter; left time: 20.3722s
# 	iters: 600, epoch: 7 | loss: 0.3807603
# 	speed: 0.0116s/iter; left time: 19.3419s
# 	iters: 700, epoch: 7 | loss: 0.3747678
# 	speed: 0.0119s/iter; left time: 18.6791s
# Epoch: 7 cost time: 9.474013090133667
# Epoch: 7, Steps: 755 | Train Loss: 0.4093925 Vali Loss: 0.5430902 Test Loss: 0.6464382
# Validation loss decreased (0.543444 --> 0.543090).  Saving model ...
# Updating learning rate to 1.5625e-05
# 	iters: 100, epoch: 8 | loss: 0.3965662
# 	speed: 0.0734s/iter; left time: 103.6374s
# 	iters: 200, epoch: 8 | loss: 0.3960504
# 	speed: 0.0121s/iter; left time: 15.8171s
# 	iters: 300, epoch: 8 | loss: 0.3751093
# 	speed: 0.0115s/iter; left time: 13.9290s
# 	iters: 400, epoch: 8 | loss: 0.4096631
# 	speed: 0.0117s/iter; left time: 12.9664s
# 	iters: 500, epoch: 8 | loss: 0.4443146
# 	speed: 0.0120s/iter; left time: 12.1273s
# 	iters: 600, epoch: 8 | loss: 0.4047786
# 	speed: 0.0120s/iter; left time: 10.9626s
# 	iters: 700, epoch: 8 | loss: 0.3874713
# 	speed: 0.0120s/iter; left time: 9.7333s
# Epoch: 8 cost time: 9.4707772731781
# Epoch: 8, Steps: 755 | Train Loss: 0.4092817 Vali Loss: 0.5432047 Test Loss: 0.6463686
# EarlyStopping counter: 1 out of 10
# Updating learning rate to 7.8125e-06
# 	iters: 100, epoch: 9 | loss: 0.3664663
# 	speed: 0.0746s/iter; left time: 48.9561s
# 	iters: 200, epoch: 9 | loss: 0.4122218
# 	speed: 0.0114s/iter; left time: 6.3345s
# 	iters: 300, epoch: 9 | loss: 0.3976279
# 	speed: 0.0113s/iter; left time: 5.1681s
# 	iters: 400, epoch: 9 | loss: 0.4020288
# 	speed: 0.0114s/iter; left time: 4.0580s
# 	iters: 500, epoch: 9 | loss: 0.3716084
# 	speed: 0.0115s/iter; left time: 2.9448s
# 	iters: 600, epoch: 9 | loss: 0.4232509
# 	speed: 0.0117s/iter; left time: 1.8275s
# 	iters: 700, epoch: 9 | loss: 0.3711795
# 	speed: 0.0117s/iter; left time: 0.6548s
# Epoch: 9 cost time: 9.298134326934814
# Epoch: 9, Steps: 755 | Train Loss: 0.4092849 Vali Loss: 0.5430138 Test Loss: 0.6463372
# Validation loss decreased (0.543090 --> 0.543014).  Saving model ...
# Updating learning rate to 3.90625e-06
# >>>>>>>testing : RLinear_traffic_ftM_sl96_pl96_dm512_ebtimeF_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 3413
# mse:0.6463, mae:0.3844, R2:0.5571
# Inference time:  13.441023111343384
