# %%
import os
import random
import sys
from argparse import Namespace
from pathlib import Path

import numpy as np
import torch

# Run from the iTransformer project root so dataset/checkpoint paths resolve correctly.
ITRANSFORMER_ROOT = (Path.cwd().parent / "models" / "itransformer").resolve()
os.chdir(ITRANSFORMER_ROOT)
sys.path.insert(0, str(ITRANSFORMER_ROOT))

# %%
from experiments.exp_long_term_forecasting import Exp_Long_Term_Forecast
from experiments.exp_long_term_forecasting_partial import Exp_Long_Term_Forecast_Partial

# User-specified arguments; everything else uses run.py defaults.
args = Namespace(
    # user-specified
    is_training=1,
    root_path="../../datasets/",
    data_path="traffic.csv",
    model_id="traffic_96_96",
    model="Informer",
    data="custom",
    features="M",
    seq_len=96,
    pred_len=96,
    e_layers=4,
    enc_in=862,
    dec_in=862,
    c_out=862,
    des="Exp",
    d_model=512,
    d_ff=512,
    batch_size=16,
    learning_rate=0.001,
    itr=1,
    # defaults from run.py
    target="OT",
    freq="h",
    checkpoints="./checkpoints/",
    label_len=48,
    n_heads=8,
    d_layers=1,
    moving_avg=25,
    factor=1,
    distil=True,
    dropout=0.1,
    embed="timeF",
    activation="gelu",
    output_attention=False,
    do_predict=False,
    num_workers=10,
    train_epochs=9,
    patience=3,
    loss="MSE",
    lradj="type1",
    use_amp=False,
    use_gpu=True,
    gpu=0,
    use_multi_gpu=False,
    devices="0,1,2,3",
    exp_name="MTSF",
    channel_independence=False,
    inverse=False,
    class_strategy="projection",
    target_root_path="./data/traffic/",
    target_data_path="traffic.csv",
    efficient_training=False,
    use_norm=True,
    partial_start_index=0,
)

fix_seed = 24
random.seed(fix_seed)
torch.manual_seed(fix_seed)
np.random.seed(fix_seed)

args.use_gpu = True if torch.cuda.is_available() and args.use_gpu else False

if args.use_gpu and args.use_multi_gpu:
    args.devices = args.devices.replace(" ", "")
    device_ids = args.devices.split(",")
    args.device_ids = [int(id_) for id_ in device_ids]
    args.gpu = args.device_ids[0]

print("Args in experiment:")
print(args)

if args.exp_name == "partial_train":
    Exp = Exp_Long_Term_Forecast_Partial
else:
    Exp = Exp_Long_Term_Forecast

if args.is_training:
    for ii in range(args.itr):
        setting = "{}_{}_{}_{}_ft{}_sl{}_ll{}_pl{}_dm{}_nh{}_el{}_dl{}_df{}_fc{}_eb{}_dt{}_{}_{}".format(
            args.model_id,
            args.model,
            args.data,
            args.features,
            args.seq_len,
            args.label_len,
            args.pred_len,
            args.d_model,
            args.n_heads,
            args.e_layers,
            args.d_layers,
            args.d_ff,
            args.factor,
            args.embed,
            args.distil,
            args.des,
            args.class_strategy,
            ii,
        )

        exp = Exp(args)
        print(">>>>>>>start training : {}>>>>>>>>>>>>>>>>>>>>>>>>>>".format(setting))
        exp.train(setting)

        print(">>>>>>>testing : {}<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<".format(setting))
        exp.test(setting)

        if args.do_predict:
            print(">>>>>>>predicting : {}<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<".format(setting))
            exp.predict(setting, True)

        torch.cuda.empty_cache()
else:
    ii = 0
    setting = "{}_{}_{}_{}_ft{}_sl{}_ll{}_pl{}_dm{}_nh{}_el{}_dl{}_df{}_fc{}_eb{}_dt{}_{}_{}".format(
        args.model_id,
        args.model,
        args.data,
        args.features,
        args.seq_len,
        args.label_len,
        args.pred_len,
        args.d_model,
        args.n_heads,
        args.e_layers,
        args.d_layers,
        args.d_ff,
        args.factor,
        args.embed,
        args.distil,
        args.des,
        args.class_strategy,
        ii,
    )

    exp = Exp(args)
    print(">>>>>>>testing : {}<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<".format(setting))
    exp.test(setting, test=1)
    torch.cuda.empty_cache()
# Out:
# Args in experiment:
# Namespace(is_training=1, root_path='../../datasets/', data_path='traffic.csv', model_id='traffic_96_96', model='Informer', data='custom', features='M', seq_len=96, pred_len=96, e_layers=4, enc_in=862, dec_in=862, c_out=862, des='Exp', d_model=512, d_ff=512, batch_size=16, learning_rate=0.001, itr=1, target='OT', freq='h', checkpoints='./checkpoints/', label_len=48, n_heads=8, d_layers=1, moving_avg=25, factor=1, distil=True, dropout=0.1, embed='timeF', activation='gelu', output_attention=False, do_predict=False, num_workers=10, train_epochs=9, patience=3, loss='MSE', lradj='type1', use_amp=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', exp_name='MTSF', channel_independence=False, inverse=False, class_strategy='projection', target_root_path='./data/traffic/', target_data_path='traffic.csv', efficient_training=False, use_norm=True, partial_start_index=0)
# Use GPU: cuda:0
# >>>>>>>start training : traffic_96_96_Informer_custom_M_ft96_sl48_ll96_pl512_dm8_nh4_el1_dl512_df1_fctimeF_ebTrue_dtExp_projection_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 12089
# val 1661
# test 3413
# 	iters: 100, epoch: 1 | loss: 0.7387764
# 	speed: 0.0528s/iter; left time: 353.3534s
# 	iters: 200, epoch: 1 | loss: 0.5477098
# 	speed: 0.0469s/iter; left time: 309.0518s
# 	iters: 300, epoch: 1 | loss: 0.5341514
# 	speed: 0.0467s/iter; left time: 303.1503s
# 	iters: 400, epoch: 1 | loss: 0.4685429
# 	speed: 0.0464s/iter; left time: 296.5264s
# 	iters: 500, epoch: 1 | loss: 0.5383406
# 	speed: 0.0460s/iter; left time: 289.6052s
# 	iters: 600, epoch: 1 | loss: 0.6266866
# 	speed: 0.0475s/iter; left time: 294.3246s
# 	iters: 700, epoch: 1 | loss: 0.6339094
# 	speed: 0.0475s/iter; left time: 289.8029s
# Epoch: 1 cost time: 36.045247316360474
# Epoch: 1, Steps: 755 | Train Loss: 0.6455862 Vali Loss: 1.0821174 Test Loss: 1.2873605
# Validation loss decreased (inf --> 1.082117).  Saving model ...
# Updating learning rate to 0.001
# 	iters: 100, epoch: 2 | loss: 0.5149273
# 	speed: 0.6927s/iter; left time: 4115.5649s
# 	iters: 200, epoch: 2 | loss: 0.5413678
# 	speed: 0.0467s/iter; left time: 272.6463s
# 	iters: 300, epoch: 2 | loss: 0.5469941
# 	speed: 0.0470s/iter; left time: 269.7834s
# 	iters: 400, epoch: 2 | loss: 0.4076768
# 	speed: 0.0468s/iter; left time: 263.8341s
# 	iters: 500, epoch: 2 | loss: 0.5975726
# 	speed: 0.0476s/iter; left time: 263.7582s
# 	iters: 600, epoch: 2 | loss: 0.4365631
# 	speed: 0.0466s/iter; left time: 253.3593s
# 	iters: 700, epoch: 2 | loss: 0.4983238
# 	speed: 0.0465s/iter; left time: 248.4657s
# Epoch: 2 cost time: 36.39493918418884
# Epoch: 2, Steps: 755 | Train Loss: 0.5229321 Vali Loss: 0.9546279 Test Loss: 1.1467761
# Validation loss decreased (1.082117 --> 0.954628).  Saving model ...
# Updating learning rate to 0.0005
# 	iters: 100, epoch: 3 | loss: 0.3880753
# 	speed: 0.6936s/iter; left time: 3596.7996s
# 	iters: 200, epoch: 3 | loss: 0.4188789
# 	speed: 0.0472s/iter; left time: 239.9962s
# 	iters: 300, epoch: 3 | loss: 0.3042883
# 	speed: 0.0465s/iter; left time: 231.6829s
# 	iters: 400, epoch: 3 | loss: 0.3979060
# 	speed: 0.0469s/iter; left time: 228.9618s
# 	iters: 500, epoch: 3 | loss: 0.4842870
# 	speed: 0.0468s/iter; left time: 223.8236s
# 	iters: 100, epoch: 7 | loss: 0.2667335
# 	speed: 0.7032s/iter; left time: 1523.0988s
# 	iters: 200, epoch: 7 | loss: 0.2768281
# 	speed: 0.0466s/iter; left time: 96.2357s
# 	iters: 300, epoch: 7 | loss: 0.2750236
# 	speed: 0.0467s/iter; left time: 91.7248s
# 	iters: 400, epoch: 7 | loss: 0.2617773
# 	speed: 0.0474s/iter; left time: 88.5012s
# 	iters: 500, epoch: 7 | loss: 0.2937362
# 	speed: 0.0469s/iter; left time: 82.7473s
# 	iters: 600, epoch: 7 | loss: 0.2930321
# 	speed: 0.0469s/iter; left time: 78.2155s
# 	iters: 700, epoch: 7 | loss: 0.2907239
# 	speed: 0.0474s/iter; left time: 74.2456s
# Epoch: 7 cost time: 36.48007798194885
# Epoch: 7, Steps: 755 | Train Loss: 0.2812228 Vali Loss: 0.7741733 Test Loss: 1.0059265
# Validation loss decreased (0.783533 --> 0.774173).  Saving model ...
# Updating learning rate to 1.5625e-05
# 	iters: 100, epoch: 8 | loss: 0.2878828
# 	speed: 0.6987s/iter; left time: 985.8104s
# 	iters: 200, epoch: 8 | loss: 0.2607546
# 	speed: 0.0469s/iter; left time: 61.5131s
# 	iters: 300, epoch: 8 | loss: 0.2457476
# 	speed: 0.0462s/iter; left time: 55.9946s
# 	iters: 400, epoch: 8 | loss: 0.2479568
# 	speed: 0.0469s/iter; left time: 52.1400s
# 	iters: 500, epoch: 8 | loss: 0.2302349
# 	speed: 0.0464s/iter; left time: 46.9529s
# 	iters: 600, epoch: 8 | loss: 0.2578501
# 	speed: 0.0469s/iter; left time: 42.7427s
# 	iters: 700, epoch: 8 | loss: 0.2861097
# 	speed: 0.0479s/iter; left time: 38.8201s
# Epoch: 8 cost time: 36.45269417762756
# Epoch: 8, Steps: 755 | Train Loss: 0.2781009 Vali Loss: 0.7730724 Test Loss: 1.0139349
# Validation loss decreased (0.774173 --> 0.773072).  Saving model ...
# Updating learning rate to 7.8125e-06
# 	iters: 100, epoch: 9 | loss: 0.3134879
# 	speed: 0.7004s/iter; left time: 459.4553s
# 	iters: 200, epoch: 9 | loss: 0.2921092
# 	speed: 0.0470s/iter; left time: 26.1050s
# 	iters: 300, epoch: 9 | loss: 0.2393282
# 	speed: 0.0470s/iter; left time: 21.4436s
# 	iters: 400, epoch: 9 | loss: 0.3107243
# 	speed: 0.0475s/iter; left time: 16.9043s
# 	iters: 500, epoch: 9 | loss: 0.2720633
# 	speed: 0.0475s/iter; left time: 12.1698s
# 	iters: 600, epoch: 9 | loss: 0.2615825
# 	speed: 0.0480s/iter; left time: 7.4884s
# 	iters: 700, epoch: 9 | loss: 0.2714834
# 	speed: 0.0465s/iter; left time: 2.6057s
# Epoch: 9 cost time: 36.74136686325073
# Epoch: 9, Steps: 755 | Train Loss: 0.2767103 Vali Loss: 0.7737499 Test Loss: 1.0175588
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 3.90625e-06
# >>>>>>>testing : traffic_96_96_Informer_custom_M_ft96_sl48_ll96_pl512_dm8_nh4_el1_dl512_df1_fctimeF_ebTrue_dtExp_projection_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 3413
# test shape: (3413, 1, 96, 862) (3413, 1, 96, 862)
# test shape: (3413, 96, 862) (3413, 96, 862)
# mse:1.0139495134353638, mae:0.5624265074729919
